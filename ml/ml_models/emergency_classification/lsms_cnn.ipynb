# %% [markdown]
# # SafeNSound: Initial Log Scaled Mel-Spectrogram Development

# %%
import os
import joblib

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa as lb
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
EMERGENCY_PATH = os.path.join("..", "..", "emergency_dataset", "emergency")
ALARMING_PATH = os.path.join("..", "..", "emergency_dataset", "alarming")
NORMAL_PATH = os.path.join("..", "..", "emergency_dataset", "non-emergency")


def load_audio_files(directory, filename):
    if not os.path.exists(directory):
        raise FileNotFoundError(f"Directory {directory} does not exist.")

    if filename.endswith('.wav'):
        file_path = os.path.join(directory, filename)
        try:
            wav, sr = lb.load(file_path, sr=16000, mono=True)
            ##wav = tf.convert_to_tensor(wav, dtype=tf.float32)
        except Exception as e:
            print(f"Error loading {file_path}: {e}")
    return wav, sr

# %%
def log_scaled_melspectrogram(audio, sample_rate, hop_length=200, frame_ms=25, n_mels=64, max_len=320):
    frame_length = int(sample_rate * frame_ms / 1000)
    n_fft = 1 << (frame_length - 1).bit_length()

    melspectrogram = lb.feature.melspectrogram(y=audio, sr=sample_rate, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)
    melS_dB = lb.power_to_db(melspectrogram, ref=np.max)

    if melS_dB.shape[1] < max_len:
        melS_dB = np.pad(melS_dB, ((0,0),(0, max_len - melS_dB.shape[1])), mode='constant')
    else:
        melS_dB = melS_dB[:, :max_len]

    S_norm = (melS_dB - melS_dB.mean()) / (melS_dB.std() + 1e-6)
    # melS_dB = melS_dB[..., np.newaxis]
    delta = lb.feature.delta(S_norm)
    delta2 = lb.feature.delta(S_norm, order=2)

    features = np.stack([S_norm, delta, delta2], axis=-1).astype(np.float32)

    return features

# %%
def augment_audio(audio, sample_rate):
    augmented = [audio]

    audio_stretched = lb.effects.time_stretch(audio, rate=0.8)
    augmented.append(audio_stretched)

    noise = np.random.normal(0, 0.003, audio.shape)
    audio_noise = audio + noise
    augmented.append(audio_noise)
    
    audio_high_pitch = lb.effects.pitch_shift(audio, sr=sample_rate, n_steps=2)
    audio_low_pitch = lb.effects.pitch_shift(audio, sr=sample_rate, n_steps=-2)
    augmented.append(audio_high_pitch)
    augmented.append(audio_low_pitch)

    noise_bg = np.random.normal(0, 0.001, audio.shape)
    audio_bg = audio + noise_bg
    augmented.append(audio_bg)

    audio_quiet = audio*0.7
    audio_loud = audio*1.3
    augmented.append(audio_quiet)
    augmented.append(audio_loud)

    return augmented

# %%
X = []
y = []
emergency_labels = {"emergency": 2, "alarming": 1, "non-emergency": 0}
file_label_pairs = []

for label, idx in emergency_labels.items():
    main_path = EMERGENCY_PATH if label == "emergency" else ALARMING_PATH if label == "alarming" else NORMAL_PATH if label == "non-emergency" else None
    if main_path is None:
        print(f"Warning: No valid path for label {label}. Skipping...")
        continue

    folder = f"{main_path}"

    if not os.path.exists(folder):
        print(f"Warning: Directory {folder} does not exist. Skipping...")
        continue

    for file in os.listdir(folder):
        if file.endswith(".wav"):
            file_label_pairs.append((os.path.join(folder, file), idx))
            
paths = [p for p,_ in file_label_pairs]
labs  = [l for _,l in file_label_pairs]

# %%
train_paths, temp_paths, train_labs, temp_labs = train_test_split(paths, labs, test_size=0.3, stratify=labs, random_state=42)
val_paths, test_paths, val_labs, test_labs = train_test_split(temp_paths, temp_labs, test_size=0.5, stratify=temp_labs, random_state=42)

train_pairs = list(zip(train_paths, train_labs))
val_pairs   = list(zip(val_paths,  val_labs))
test_pairs  = list(zip(test_paths, test_labs))

# %%
def gen(pairs):
    for fp, idx in pairs:
        wav, sr = lb.load(fp, sr=16000, mono=True)
        for aug in augment_audio(wav, sr):
            feat = log_scaled_melspectrogram(aug, sr)
            yield feat, keras.utils.to_categorical(idx, num_classes=3)

# %%
spec = (tf.TensorSpec(shape=(64, 320, 3), dtype=tf.float32),
        tf.TensorSpec(shape=(3,), dtype=tf.float32))

train_ds = tf.data.Dataset.from_generator(lambda: gen(train_pairs), output_signature=spec)\
                        .shuffle(1024).batch(32).prefetch(tf.data.AUTOTUNE)
val_ds   = tf.data.Dataset.from_generator(lambda: gen(val_pairs), output_signature=spec)\
                        .batch(32).prefetch(tf.data.AUTOTUNE)
test_ds  = tf.data.Dataset.from_generator(lambda: gen(test_pairs), output_signature=spec)\
                        .batch(32).prefetch(tf.data.AUTOTUNE)

# %%
def build_cnn(input_shape, num_classes):
    model = models.Sequential([
        # Conv Block 1
        layers.Conv2D(32, 3, activation='relu', padding='same', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Dropout(0.3),

        # Conv Block 2
        layers.Conv2D(64, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Dropout(0.3),

        # Conv Block 3
        layers.Conv2D(128, 3, activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(2),
        layers.Dropout(0.3),

        # Flatten + Dense
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.4),
        layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
input_shape = (64, 320, 3) #nmel, max_len, channels
model = build_cnn(input_shape, num_classes=3)
model.summary()
# Out:
# c:\Users\Acer\Documents\GitHub\SafeNSound-An-IoT-Based-Distress-Signals-Detection-for-Semi-private-Rooms-using-Sound-Sensor\myenv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 64, 320, 32)    │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 320, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 160, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32, 160, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 160, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 160, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 80, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 16, 80, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 80, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 80, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 40, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 8, 40, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 40960)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     5,243,008 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │           387 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,337,539 (20.36 MB)
#  Trainable params: 5,337,091 (20.36 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(train_ds, epochs=50, validation_data=val_ds)
test_loss, test_acc = model.evaluate(test_ds)
print("Test accuracy:", test_acc)
# Out:
# Epoch 1/50
#     613/Unknown 566s 832ms/step - accuracy: 0.5362 - loss: 2.4313
# c:\Users\Acer\Documents\GitHub\SafeNSound-An-IoT-Based-Distress-Signals-Detection-for-Semi-private-Rooms-using-Sound-Sensor\myenv\lib\site-packages\keras\src\trainers\epoch_iterator.py:164: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 640s 952ms/step - accuracy: 0.5631 - loss: 1.2261 - val_accuracy: 0.6236 - val_loss: 0.9950
# Epoch 2/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 568s 903ms/step - accuracy: 0.6435 - loss: 0.7660 - val_accuracy: 0.7110 - val_loss: 0.6491
# Epoch 3/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 564s 893ms/step - accuracy: 0.7065 - loss: 0.6481 - val_accuracy: 0.7462 - val_loss: 0.6073
# Epoch 4/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 543s 862ms/step - accuracy: 0.7514 - loss: 0.5614 - val_accuracy: 0.7621 - val_loss: 0.6767
# Epoch 5/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 559s 886ms/step - accuracy: 0.7994 - loss: 0.4667 - val_accuracy: 0.8081 - val_loss: 0.5759
# Epoch 6/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 574s 910ms/step - accuracy: 0.8242 - loss: 0.4190 - val_accuracy: 0.8226 - val_loss: 0.5487
# Epoch 7/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 545s 864ms/step - accuracy: 0.8566 - loss: 0.3418 - val_accuracy: 0.6705 - val_loss: 2.2392
# Epoch 8/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 553s 880ms/step - accuracy: 0.8735 - loss: 0.3017 - val_accuracy: 0.8190 - val_loss: 0.8206
# Epoch 9/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 614s 978ms/step - accuracy: 0.8953 - loss: 0.2453 - val_accuracy: 0.8512 - val_loss: 0.6234
# Epoch 10/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 730s 1s/step - accuracy: 0.9063 - loss: 0.2354 - val_accuracy: 0.8412 - val_loss: 0.7335
# Epoch 11/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 538s 854ms/step - accuracy: 0.9146 - loss: 0.2068 - val_accuracy: 0.8640 - val_loss: 0.6807
# Epoch 12/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 535s 849ms/step - accuracy: 0.9180 - loss: 0.2043 - val_accuracy: 0.8629 - val_loss: 0.5960
# Epoch 13/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━
50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 1000s 2s/step - accuracy: 0.9718 - loss: 0.0744 - val_accuracy: 0.8795 - val_loss: 0.9597
# Epoch 38/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 1009s 2s/step - accuracy: 0.9688 - loss: 0.0824 - val_accuracy: 0.8707 - val_loss: 1.3121
# Epoch 39/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 1067s 2s/step - accuracy: 0.9701 - loss: 0.0772 - val_accuracy: 0.8714 - val_loss: 1.1251
# Epoch 40/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 1003s 2s/step - accuracy: 0.9701 - loss: 0.0828 - val_accuracy: 0.8702 - val_loss: 0.9325
# Epoch 41/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 15383s 25s/step - accuracy: 0.9709 - loss: 0.0742 - val_accuracy: 0.8729 - val_loss: 0.8341
# Epoch 42/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 571s 906ms/step - accuracy: 0.9733 - loss: 0.0712 - val_accuracy: 0.8736 - val_loss: 0.8832
# Epoch 43/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 556s 883ms/step - accuracy: 0.9703 - loss: 0.0762 - val_accuracy: 0.8710 - val_loss: 0.9663
# Epoch 44/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 560s 887ms/step - accuracy: 0.9712 - loss: 0.0704 - val_accuracy: 0.8821 - val_loss: 0.9448
# Epoch 45/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 559s 888ms/step - accuracy: 0.9751 - loss: 0.0651 - val_accuracy: 0.8850 - val_loss: 0.6728
# Epoch 46/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 558s 884ms/step - accuracy: 0.9739 - loss: 0.0746 - val_accuracy: 0.8781 - val_loss: 0.9483
# Epoch 47/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 559s 887ms/step - accuracy: 0.9767 - loss: 0.0626 - val_accuracy: 0.8860 - val_loss: 0.8260
# Epoch 48/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 588s 934ms/step - accuracy: 0.9726 - loss: 0.0741 - val_accuracy: 0.8869 - val_loss: 1.1866
# Epoch 49/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 566s 897ms/step - accuracy: 0.9711 - loss: 0.0848 - val_accuracy: 0.8790 - val_loss: 0.8347
# Epoch 50/50
# 613/613 ━━━━━━━━━━━━━━━━━━━━ 555s 881ms/step - accuracy: 0.9753 - loss: 0.0642 - val_accuracy: 0.8633 - val_loss: 1.1075
# 132/132 ━━━━━━━━━━━━━━━━━━━━ 80s 606ms/step - accuracy: 0.8629 - loss: 0.9563
# Test accuracy: 0.8628571629524231

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_true = []
y_pred = []

for features, labels in test_ds:
    predictions = model.predict(features, verbose=0)
    y_pred.extend(np.argmax(predictions, axis=1))
    y_true.extend(np.argmax(labels.numpy(), axis=1))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['non-emergency', 'alarming', 'emergency'],
            yticklabels=['non-emergency', 'alarming', 'emergency'])
plt.title('Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
accuracy = accuracy_score(y_true, y_pred)
class_report = classification_report(y_true, y_pred, target_names=["non-emergency", "alarming", "emergency"])

print(f"Accuracy: {accuracy*100:.2f}%")
print("Classification Report:", class_report)
# Out:
# Accuracy: 86.21%
# Classification Report:                precision    recall  f1-score   support
#
# non-emergency       0.82      0.88      0.85      1296
#      alarming       0.92      0.68      0.78      1072
#     emergency       0.87      0.95      0.91      1832
#
#      accuracy                           0.86      4200
#     macro avg       0.87      0.84      0.85      4200
#  weighted avg       0.87      0.86      0.86      4200

# %%
model.save('lsms_cnn_model_9.keras')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_spec.supported_ops = [
    tf.lite.OpsSet.TFLITE_BUILTINS,  # Use older compatible ops
]
tflite_model = converter.convert()

# Save the new model
with open("lsms_cnn_model_9.tflite", "wb") as f:
    f.write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: C:\Users\Acer\AppData\Local\Temp\tmp_rfmpj6k\assets
# INFO:tensorflow:Assets written to: C:\Users\Acer\AppData\Local\Temp\tmp_rfmpj6k\assets
# Saved artifact at 'C:\Users\Acer\AppData\Local\Temp\tmp_rfmpj6k'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 320, 3), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   1659827449952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827442912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827444320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827451888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827447664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827449424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827452944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827453648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827702240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827700304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827701536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827701184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1658208690672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827705408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827703120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827705936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827704176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827704528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827707520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827708224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827704704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1659827710336: TensorSpec(shape=(), dtype=tf.resource, name=None)
